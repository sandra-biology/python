# %%
# %matplotlib inline

a = [10, 20, 30, 40]
print a
import matplotlib.pyplot as plt

plt.plot([0, 1, 2, 3, 4, 5, 6], [0, 1, 4, 9, 16, 25, 36])
plt.show()
# Out:
# [10, 20, 30, 40]

# %%
import numpy as np
xsin = np.linspace(0, 2*np.pi, 100+1)
ysin = np.sin(xsin)
plt.plot(xsin,ysin)
plt.show()
